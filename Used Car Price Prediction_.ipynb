# %% [markdown]
# Libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import datetime

# %% [markdown]
# Read and Understand data

# %%
df=pd.read_csv("Cars.csv",index_col=0)
df.head()
# Out:
#                    Location    Year  Kilometers_Driven Fuel_Type Transmission  \
# Name
# Mahindra Scorpio       Pune  2012.0            99000.0    Diesel       Manual
# Maruti Baleno         Kochi  2018.0            18678.0    Petrol       Manual
# Mahindra Xylo     Bangalore  2013.0           197000.0    Diesel       Manual
# Hyundai Grand         Delhi  2014.0            45000.0    Diesel       Manual
# Toyota Innova         Delhi  2011.0            65000.0    Diesel       Manual
#
#                  Owner_Type     Mileage   Engine    Power        Colour  \
# Name
# Mahindra Scorpio      Third  12.05 kmpl  2179 CC  120 bhp  Black/Silver
# Maruti Baleno         First   21.1 kmpl   998 CC  100 bhp        Others
# Mahindra Xylo         First  11.68 kmpl  2498 CC  112 bhp         White
# Hyundai Grand         First   24.0 kmpl  1120 CC   70 bhp         White
# Toyota Innova         First   12.8 kmpl  2494 CC  102 bhp        Others
#
#                   Seats  No. of Doors New_Price  Price
# Name
# Mahindra Scorpio    8.0           5.0       NaN   6.00
# Maruti Baleno       5.0           4.0       NaN   8.32
# Mahindra Xylo       7.0           5.0       NaN   4.00
# Hyundai Grand       5.0           4.0       NaN   3.49
# Toyota Innova       8.0           5.0       NaN   6.40

# %%
df.shape
# Out:
# (5961, 14)

# %%
#checking missing values in each column
df.isna().sum()
# Out:
# Location               11
# Year                    2
# Kilometers_Driven       8
# Fuel_Type               0
# Transmission           27
# Owner_Type             15
# Mileage                 2
# Engine                 17
# Power                  32
# Colour                 11
# Seats                   5
# No. of Doors            1
# New_Price            5137
# Price                   0
# dtype: int64

# %%
#unique values in each column
df.nunique()
# Out:
# Location               11
# Year                   22
# Kilometers_Driven    3068
# Fuel_Type               5
# Transmission            2
# Owner_Type              4
# Mileage               439
# Engine                143
# Power                 369
# Colour                  3
# Seats                   8
# No. of Doors            3
# New_Price             540
# Price                1369
# dtype: int64

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5961 entries, Mahindra Scorpio to Hyundai i10
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Location           5950 non-null   object
#  1   Year               5959 non-null   float64
#  2   Kilometers_Driven  5953 non-null   float64
#  3   Fuel_Type          5961 non-null   object
#  4   Transmission       5934 non-null   object
#  5   Owner_Type         5946 non-null   object
#  6   Mileage            5959 non-null   object
#  7   Engine             5944 non-null   object
#  8   Power              5929 non-null   object
#  9   Colour             5950 non-null   object
#  10  Seats              5956 non-null   float64
#  11  No. of Doors       5960 non-null   float64
#  12  New_Price          824 non-null    object
#  13  Price              5961 non-null   float64
# dtypes: float64(5), object(9)
# memory usage: 698.6+ KB
#               Year  Kilometers_Driven        Seats  No. of Doors        Price
# count  5959.000000       5.953000e+03  5956.000000   5960.000000  5961.000000
# mean   2013.389159       5.871110e+04     5.269140      4.114933     9.528103
# std       3.243051       9.171221e+04     0.789048      0.344757    11.214382
# min    1998.000000       1.710000e+02     2.000000      2.000000     0.440000
# 25%    2011.500000       3.393100e+04     5.000000      4.000000     3.500000
# 50%    2014.000000       5.300000e+04     5.000000      4.000000     5.660000
# 75%    2016.000000       7.300000e+04     5.000000      4.000000    10.000000
# max    2019.000000       6.500000e+06    10.000000      5.000000   160.000000

# %%
#visuallizing missing values
#these yellow lines represent missing values
plt.figure(figsize=(14,6))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: ylabel='Name'>

# %%
print( "Percent of missing :\n\n", round(df.isna().sum() / df.isna().count() * 100, 2))
# Out:
# Percent of missing :
#
#  Location              0.18
# Year                  0.03
# Kilometers_Driven     0.13
# Fuel_Type             0.00
# Transmission          0.45
# Owner_Type            0.25
# Mileage               0.03
# Engine                0.29
# Power                 0.54
# Colour                0.18
# Seats                 0.08
# No. of Doors          0.02
# New_Price            86.18
# Price                 0.00
# dtype: float64

# %% [markdown]
#  A categorical variable is a type of variable that represents distinct categories or groups, and it can take on values that belong to these categories.
# For example, "color" can be a categorical variable with categories like red, blue, and green.

# %%
#list of categorical variables
lst=['Location','Fuel_Type','Transmission','Owner_Type','Seats','No. of Doors','Colour','Year']
for i in lst:
    print(i,"\n")
    print(df[i].value_counts())
    print('-'*50)
# Out:
# Location
#
# Mumbai        781
# Hyderabad     739
# Kochi         646
# Coimbatore    630
# Pune          611
# Delhi         549
# Kolkata       526
# Chennai       489
# Jaipur        406
# Bangalore     351
# Ahmedabad     222
# Name: Location, dtype: int64
# --------------------------------------------------
# Fuel_Type
#
# Diesel      3188
# Petrol      2705
# CNG           56
# LPG           10
# Electric       2
# Name: Fuel_Type, dtype: int64
# --------------------------------------------------
# Transmission
#
# Manual       4225
# Automatic    1709
# Name: Transmission, dtype: int64
# --------------------------------------------------
# Owner_Type
#
# First             4875
# Second             953
# Third              110
# Fourth & Above       8
# Name: Owner_Type, dtype: int64
# --------------------------------------------------
# Seats
#
# 5.0     5013
# 7.0      674
# 8.0      117
# 4.0       99
# 6.0       31
# 2.0       17
# 10.0       3
# 9.0        2
# Name: Seats, dtype: int64
# --------------------------------------------------
# No. of Doors
#
# 4.0    5224
# 5.0     719
# 2.0      17
# Name: No. of Doors, dtype: int64
# --------------------------------------------------
# Colour
#
# White           2115
# Others          1987
# Black/Silver    1848
# Name: Colour, dtype: int64
# --------------------------------------------------
# Year
#
# 2014.0    793
# 2016.0    740
# 2015.0    736
# 2013.0    642
# 2017.0    586
# 2012.0    573
# 2011.0    461
# 2010.0    338
# 2018.0    298
# 2009.0    196
# 2008.0    170
# 2007.0    123
# 2019.0    101
# 2006.0     75
# 2005.0     55
# 2004.0     28
# 2002.0     14
# 2003.0     13
# 2001.0      7
# 2000.0      4
# 1998.0      4
# 1999.0      2
# Name: Year, dtype: int64
# --------------------------------------------------

# %% [raw]
# Maximum car being sold have fuel type as Diesel(3188 cars).
# Mumbai has highest numbers of car availabe for purchase(781 cars).
# 4225 cars with Manual transmission are available for purchase.
# Most of the cars are 5 seaters and First owned.
# Years of car ranges form 1999- 2014.

# %% [markdown]
# Data Preprocessing

# %%
np.random.seed(9)
df[['Engine','Power','Mileage']].sample(10)
# Out:
#                   Engine       Power     Mileage
# Name
# Ford Figo        1498 CC      99 bhp  25.83 kmpl
# Nissan Terrano   1461 CC   83.14 bhp  19.87 kmpl
# Maruti Alto       998 CC    67.1 bhp  24.07 kmpl
# Maruti Eeco      1196 CC      73 bhp   15.1 kmpl
# Toyota Innova    2755 CC   171.5 bhp  11.36 kmpl
# Jaguar F         5000 CC   488.1 bhp   12.5 kmpl
# Toyota Innova    2494 CC     102 bhp   12.8 kmpl
# Volkswagen Polo  1498 CC      88 bhp  20.14 kmpl
# Maruti Celerio    998 CC   67.04 bhp   23.1 kmpl
# Tata Hexa        2179 CC  153.86 bhp   17.6 kmpl

# %% [raw]
# Dropping units from mileages,Engine and Power.

# %%
df["Mileage"] = df["Mileage"].str.rstrip(" kmpl")
df["Mileage"] = df["Mileage"].str.rstrip(" km/g")

df["Engine"] = df["Engine"].str.rstrip(" CC")

df["Power"] = df["Power"].str.rstrip(" bhp")

# %%
df[['Engine','Power','Mileage']].sample(5)
#units removed
# Out:
#                 Engine  Power Mileage
# Name
# Toyota Innova     2494  100.6   12.99
# Toyota Etios      1496   88.7    17.6
# Hyundai i20       1197     80    18.5
# Hyundai Verna     1591  121.3   15.74
# Mahindra XUV500   2179    140    16.0

# %%
df.loc[df["Mileage"] == '0.0', 'Mileage'].count()
# Out:
# 56

# %% [raw]
# there are 56 values where mileage is zero.

# %%
print(df["Transmission"].unique())
# Out:
# ['Manual' 'Automatic' nan]

# %% [raw]
# Converting object data type to category data type.
# Replacing null or nan values with "unknown" so that we convert its type to "category"

# %%
df["Transmission"] = df["Transmission"].replace('null', 'Unknown').astype("category")

# %%
df["Fuel_Type"] = df["Fuel_Type"].astype("category")
df["Owner_Type"] = df["Owner_Type"].astype("category")

#converting datatype  
df["Mileage"] = df["Mileage"].astype(float)
df["Engine"]=df["Engine"].astype(float)

# %% [raw]
# Replacing null values in Power column with 0 (zero)

# %%
#handle null values
df["Power"] = df["Power"].replace('null', 0).astype(float)

# %%
df.describe().T
#T for transpose
# Out:
#                     count          mean           std      min       25%  \
# Year               5959.0   2013.389159      3.243051  1998.00   2011.50
# Kilometers_Driven  5953.0  58711.100118  91712.207172   171.00  33931.00
# Mileage            5959.0     18.184499      4.524639     0.00     15.26
# Engine             5944.0   1622.552995    601.689666    72.00   1198.00
# Power              5929.0    111.463508     55.481567     0.00     74.00
# Seats              5956.0      5.269140      0.789048     2.00      5.00
# No. of Doors       5960.0      4.114933      0.344757     2.00      4.00
# Price              5961.0      9.528103     11.214382     0.44      3.50
#
#                         50%      75%         max
# Year                2014.00   2016.0     2019.00
# Kilometers_Driven  53000.00  73000.0  6500000.00
# Mileage               18.16     21.1       33.54
# Engine              1493.00   1984.0     5998.00
# Power                 93.70    138.1      560.00
# Seats                  5.00      5.0       10.00
# No. of Doors           4.00      4.0        5.00
# Price                  5.66     10.0      160.00

# %% [markdown]
# Feature Engineering

# %% [raw]
# calculating age of car for better analysis

# %%
current_year = datetime.datetime.now().year
df['Age']=current_year - df['Year']

# %%
df.columns
#Age column added
# Out:
# Index(['Location', 'Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission',
#        'Owner_Type', 'Mileage', 'Engine', 'Power', 'Colour', 'Seats',
#        'No. of Doors', 'New_Price', 'Price', 'Age'],
#       dtype='object')

# %% [raw]
# Now, we will extract the brand name and the model name from the 'Name'.
# WHY? model name and brand name might help us predict the price.

# %% [raw]
# Right now 'Name' is not a column, it is the index of dataframe.
# Resetting the index of DataFrame, which will make 'Name' a regular column.

# %%
df.reset_index(inplace=True)

# %%
df.head(2)
#Notice, Name is a column now.
# Out:
#                Name Location    Year  Kilometers_Driven Fuel_Type  \
# 0  Mahindra Scorpio     Pune  2012.0            99000.0    Diesel
# 1     Maruti Baleno    Kochi  2018.0            18678.0    Petrol
#
#   Transmission Owner_Type  Mileage  Engine  Power        Colour  Seats  \
# 0       Manual      Third    12.05  2179.0  120.0  Black/Silver    8.0
# 1       Manual      First    21.10   998.0  100.0        Others    5.0
#
#    No. of Doors New_Price  Price   Age
# 0           5.0       NaN   6.00  11.0
# 1           4.0       NaN   8.32   5.0

# %% [raw]
# Checking if column 'Name' has missing values.

# %%
df[df['Name'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Name, Location, Year, Kilometers_Driven, Fuel_Type, Transmission, Owner_Type, Mileage, Engine, Power, Colour, Seats, No. of Doors, New_Price, Price, Age]
# Index: []

# %%
#making modifications so that correct model name and brand name is assigned to car.
df["Name"] = df["Name"].str.replace('Land Rover', 'Landrover')
df["Name"] = df["Name"].str.replace('Mini Cooper', 'MiniCooper')

#Extracting Brand Name and Model Name
df['Brand'] = df['Name'].str.split(' ').str[0] #Separating Brand name from the Name
df['Model'] = df['Name'].str.split(' ').str[1] #Separating Model name from the Name

# %%
print('Brand name')
print(df['Brand'].unique())
print('\n Model name')
print(df['Model'].unique())
# Out:
# Brand name
# ['Mahindra' 'Maruti' 'Hyundai' 'Toyota' 'Honda' 'Chevrolet' 'Audi' 'Skoda'
#  'Renault' 'Landrover' 'BMW' 'ISUZU' 'Jaguar' 'Mercedes-Benz' 'Volkswagen'
#  'Tata' 'Mitsubishi' 'Ford' 'Nissan' 'Volvo' 'Fiat' 'Porsche' 'MiniCooper'
#  'Datsun' 'Jeep' 'Force' 'Isuzu' 'Smart' 'Lamborghini' 'Mini' 'Bentley']
#
#  Model name
# ['Scorpio' 'Baleno' 'Xylo' 'Grand' 'Innova' 'WRV' 'Verna' 'Fortuner'
#  'Beat' 'A6' 'i20' 'Laura' 'City' 'Q7' 'Duster' 'Ertiga' 'Freelander'
#  'Rapid' 'Zen' '3' 'Wagon' 'Jazz' 'Vitara' 'D-MAX' 'SX4' 'i10' 'Amaze'
#  'Xcent' 'F' 'C-Class' 'Polo' '5' 'Thar' 'Alto' 'A3' 'Xenon' 'X1' 'Getz'
#  'Vento' 'Sail' 'Jetta' 'Ciaz' 'CR-V' 'XUV500' 'New' 'Civic' 'Superb'
#  'Ritz' 'Pajero' 'Corolla' 'Elantra' 'Figo' 'EON' 'Teana' 'Swift' 'CLA'
#  'Range' 'Q3' 'Fiesta' 'Indica' 'Ecosport' 'S80' 'Fabia' 'A4' 'E-Class'
#  'Brio' 'Discovery' 'Ikon' 'Santa' 'Bolero' 'Dzire' 'KWID' 'Celerio'
#  'Optra' 'GLC' 'X3' 'Micra' 'Etios' 'Creta' 'Endeavour' '7' 'X5' 'Octavia'
#  'Zest' 'Scala' 'B' 'EcoSport' 'TUV' 'Hexa' 'Elite' 'Accent' 'GLE' 'Linea'
#  'Omni' 'Q5' 'Passat' 'Panamera' 'BRV' nan 'Indigo' 'A-Star' 'Nano'
#  'Santro' 'Tiguan' 'R-Class' 'Accord' 'GO' 'Aspire' 'Camry' 'Cruze'
#  'Sunny' 'redi-GO' 'Compass' 'RS5' 'S60' 'Punto' 'XC60' 'Mobilio' 'Manza'
#  'S' 'Eeco' 'GLA' 'Bolt' '6' 'Grande' 'Esteem' 'M-Class' 'TT' 'Yeti'
#  'Ameo' 'Logan' 'Pulse' 'Ignis' 'GL-Class' 'XF' 'Lancer' 'SLC' 'Cayenne'
#  'A' 'Avventura' 'Safari' 'Terrano' '800' 'S-Class' 'Aveo' 'Mustang' 'V40'
#  'A7' 'Sumo' 'One' 'Tiago' 'Verito' 'CLS-Class' 'Platinum' 'SLK-Class'
#  'X-Trail' 'Z4' 'Cedia' 'XJ' 'Enjoy' 'XUV300' 'Cayman' 'Spark' 'KUV'
#  'Sonata' 'Quanto' 'Renault' 'CrossPolo' 'Captur' 'SL-Class' 'Jeep'
#  'S-Cross' 'Fluence' 'Fusion' 'MUX' 'X6' 'Qualis' '1000' 'Outlander'
#  'Ssangyong' 'Fortwo' 'Koleos' 'Tigor' 'GLS' 'Evalia' 'Nexon' 'BR-V' 'XE'
#  '1' 'Freestyle' 'Siena' 'Classic' 'WR-V' 'NuvoSport' 'Gallardo' 'Montero'
#  'Redi' 'Countryman' 'Prius' 'Petra' 'XC90' 'Tucson' 'A8' 'Beetle'
#  'Continental' 'Captiva' 'Clubman' 'Boxster' 'E']

# %%
sorted(df['Brand'].unique())
# Out:
# ['Audi',
#  'BMW',
#  'Bentley',
#  'Chevrolet',
#  'Datsun',
#  'Fiat',
#  'Force',
#  'Ford',
#  'Honda',
#  'Hyundai',
#  'ISUZU',
#  'Isuzu',
#  'Jaguar',
#  'Jeep',
#  'Lamborghini',
#  'Landrover',
#  'Mahindra',
#  'Maruti',
#  'Mercedes-Benz',
#  'Mini',
#  'MiniCooper',
#  'Mitsubishi',
#  'Nissan',
#  'Porsche',
#  'Renault',
#  'Skoda',
#  'Smart',
#  'Tata',
#  'Toyota',
#  'Volkswagen',
#  'Volvo']

# %% [raw]
# Notice in brand names : 'ISUZU' , 'isuzu'.
# Correcting brand names.

# %%
df.loc[df.Brand == 'ISUZU','Brand']='Isuzu'

# %%
df.Model.isnull().sum()
# Out:
# 24

# %% [raw]
# Droppings row having model values as null.

# %%
df.dropna(subset=['Model'],axis=0,inplace=True)

# %%
sorted(df['Model'].unique())
# Out:
# ['1',
#  '1000',
#  '3',
#  '5',
#  '6',
#  '7',
#  '800',
#  'A',
#  'A-Star',
#  'A3',
#  'A4',
#  'A6',
#  'A7',
#  'A8',
#  'Accent',
#  'Accord',
#  'Alto',
#  'Amaze',
#  'Ameo',
#  'Aspire',
#  'Aveo',
#  'Avventura',
#  'B',
#  'BR-V',
#  'BRV',
#  'Baleno',
#  'Beat',
#  'Beetle',
#  'Bolero',
#  'Bolt',
#  'Boxster',
#  'Brio',
#  'C-Class',
#  'CLA',
#  'CLS-Class',
#  'CR-V',
#  'Camry',
#  'Captiva',
#  'Captur',
#  'Cayenne',
#  'Cayman',
#  'Cedia',
#  'Celerio',
#  'Ciaz',
#  'City',
#  'Civic',
#  'Classic',
#  'Clubman',
#  'Compass',
#  'Continental',
#  'Corolla',
#  'Countryman',
#  'Creta',
#  'CrossPolo',
#  'Cruze',
#  'D-MAX',
#  'Discovery',
#  'Duster',
#  'Dzire',
#  'E',
#  'E-Class',
#  'EON',
#  'EcoSport',
#  'Ecosport',
#  'Eeco',
#  'Elantra',
#  'Elite',
#  'Endeavour',
#  'Enjoy',
#  'Ertiga',
#  'Esteem',
#  'Etios',
#  'Evalia',
#  'F',
#  'Fabia',
#  'Fiesta',
#  'Figo',
#  'Fluence',
#  'Fortuner',
#  'Fortwo',
#  'Freelander',
#  'Freestyle',
#  'Fusion',
#  'GL-Class',
#  'GLA',
#  'GLC',
#  'GLE',
#  'GLS',
#  'GO',
#  'Gallardo',
#  'Getz',
#  'Grand',
#  'Grande',
#  'Hexa',
#  'Ignis',
#  'Ikon',
#  'Indica',
#  'Indigo',
#  'Innova',
#  'Jazz',
#  'Jeep',
#  'Jetta',
#  'KUV',
#  'KWID',
#  'Koleos',
#  'Lancer',
#  'Laura',
#  'Linea',
#  'Logan',
#  'M-Class',
#  'MUX',
#  'Manza',
#  'Micra',
#  'Mobilio',
#  'Montero',
#  'Mustang',
#  'Nano',
#  'New',
#  'Nexon',
#  'NuvoSport',
#  'Octavia',
#  'Omni',
#  'One',
#  'Optra',
#  'Outlander',
#  'Pajero',
#  'Panamera',
#  'Passat',
#  'Petra',
#  'Platinum',
#  'Polo',
#  'Prius',
#  'Pulse',
#  'Punto',
#  'Q3',
#  'Q5',
#  'Q7',
#  'Qualis',
#  'Quanto',
#  'R-Class',
#  'RS5',
#  'Range',
#  'Rapid',
#  'Redi',
#  'Renault',
#  'Ritz',
#  'S',
#  'S-Class',
#  'S-Cross',
#  'S60',
#  'S80',
#  'SL-Class',
#  'SLC',
#  'SLK-Class',
#  'SX4',
#  'Safari',
#  'Sail',
#  'Santa',
#  'Santro',
#  'Scala',
#  'Scorpio',
#  'Siena',
#  'Sonata',
#  'Spark',
#  'Ssangyong',
#  'Sumo',
#  'Sunny',
#  'Superb',
#  'Swift',
#  'TT',
#  'TUV',
#  'Teana',
#  'Terrano',
#  'Thar',
#  'Tiago',
#  'Tigor',
#  'Tiguan',
#  'Tucson',
#  'V40',
#  'Vento',
#  'Verito',
#  'Verna',
#  'Vitara',
#  'WR-V',
#  'WRV',
#  'Wagon',
#  'X-Trail',
#  'X1',
#  'X3',
#  'X5',
#  'X6',
#  'XC60',
#  'XC90',
#  'XE',
#  'XF',
#  'XJ',
#  'XUV300',
#  'XUV500',
#  'Xcent',
#  'Xenon',
#  'Xylo',
#  'Yeti',
#  'Z4',
#  'Zen',
#  'Zest',
#  'i10',
#  'i20',
#  'redi-GO']

# %%
df[(df['Model'] == 'BR-V') | (df['Model'] == 'BRV')]
# Out:
#             Name   Location    Year  Kilometers_Driven Fuel_Type Transmission  \
# 306    Honda BRV     Mumbai  2017.0            17000.0    Petrol    Automatic
# 2564   Honda BRV     Mumbai  2017.0            18000.0    Petrol    Automatic
# 2770  Honda BR-V  Bangalore  2016.0            34004.0    Petrol       Manual
# 2789   Honda BRV       Pune  2016.0             9200.0    Petrol       Manual
# 3845   Honda BRV     Mumbai  2017.0            16503.0    Petrol    Automatic
# 3891  Honda BR-V       Pune  2017.0             9000.0    Petrol       Manual
# 4936  Honda BR-V      Kochi  2017.0            32249.0    Diesel       Manual
# 5394   Honda BRV      Kochi  2017.0            35676.0    Petrol    Automatic
#
#      Owner_Type  Mileage  Engine  Power        Colour  Seats  No. of Doors  \
# 306       First     16.0  1497.0  117.3  Black/Silver    7.0           5.0
# 2564      First     16.0  1497.0  117.3        Others    7.0           5.0
# 2770      First     15.4  1497.0  117.3        Others    7.0           5.0
# 2789      First     15.4  1497.0  117.3         White    7.0           5.0
# 3845      First     16.0  1497.0  117.3        Others    7.0           5.0
# 3891      First     15.4  1497.0  117.3  Black/Silver    7.0           5.0
# 4936      First     21.9  1498.0   98.6         White    7.0           5.0
# 5394      First     16.0  1497.0  117.3         White    7.0           5.0
#
#        New_Price  Price  Age  Brand Model
# 306   15.02 Lakh   9.50  6.0  Honda   BRV
# 2564  15.02 Lakh   9.25  6.0  Honda   BRV
# 2770   12.9 Lakh   8.02  7.0  Honda  BR-V
# 2789  13.58 Lakh   8.00  7.0  Honda   BRV
# 3845  15.02 Lakh   9.50  6.0  Honda   BRV
# 3891  12.51 Lakh   8.50  6.0  Honda  BR-V
# 4936  15.45 Lakh  10.79  6.0  Honda  BR-V
# 5394  14.65 Lakh   9.48  6.0  Honda   BRV

# %% [raw]
# Notice in model names : 'BRV' , 'BR-V', 'EcoSport' , 'Ecosport'.
# Correcting model names.

# %%
df.loc[df.Model == 'BR-v','Brand']='BRV'
df.loc[df.Model == 'EcoSport','Brand']='Ecosport'

# %%
df.Model.nunique()
# Out:
# 208

# %% [raw]
# Top 5 most popular models

# %%
df.groupby('Model')['Model'].size().nlargest(5)
# Out:
# Model
# Swift     343
# City      265
# i20       247
# Verna     170
# Innova    164
# Name: Model, dtype: int64

# %% [markdown]
# EDA

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5937 entries, 0 to 5960
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               5937 non-null   object
#  1   Location           5926 non-null   object
#  2   Year               5935 non-null   float64
#  3   Kilometers_Driven  5929 non-null   float64
#  4   Fuel_Type          5937 non-null   category
#  5   Transmission       5910 non-null   category
#  6   Owner_Type         5922 non-null   category
#  7   Mileage            5935 non-null   float64
#  8   Engine             5920 non-null   float64
#  9   Power              5905 non-null   float64
#  10  Colour             5926 non-null   object
#  11  Seats              5932 non-null   float64
#  12  No. of Doors       5936 non-null   float64
#  13  New_Price          809 non-null    object
#  14  Price              5937 non-null   float64
#  15  Age                5935 non-null   float64
#  16  Brand              5937 non-null   object
#  17  Model              5937 non-null   object
# dtypes: category(3), float64(9), object(6)
# memory usage: 760.0+ KB
#               Year  Kilometers_Driven      Mileage       Engine        Power  \
# count  5935.000000       5.929000e+03  5935.000000  5920.000000  5905.000000
# mean   2013.382982       5.884245e+04    18.181700  1622.047128   111.318838
# std       3.245917       9.186953e+04     4.528727   602.672396    55.500001
# min    1998.000000       1.710000e+02     0.000000    72.000000     0.000000
# 25%    2011.000000       3.400000e+04    15.200000  1198.000000    74.000000
# 50%    2014.000000       5.310500e+04    18.160000  1493.000000    91.720000
# 75%    2016.000000       7.300000e+04    21.100000  1984.000000   138.100000
# max    2019.000000       6.500000e+06    33.540000  5998.000000   560.000000
#
#              Seats  No. of Doors        Price          Age
# count  5932.000000   5936.000000  5937.000000  5935.000000
# mean      5.272758      4.115398     9.458599     9.617018
# std       0.787985      0.345376    11.176953     3.245917
# min       2.000000      2.000000     0.440000     4.000000
# 25%       5.000000      4.000000     3.500000     7.000000
# 50%       5.000000      4.000000     5.650000     9.000000
# 75%       5.000000      4.000000     9.900000    12.000000
# max      10.000000      5.000000   160.000000    25.000000

# %% [raw]
# 160 lakhs price is for an used car is quite high, seems to be an outlier.
# Age of car is between 4 years old to 25 years old
# Years ranges from 1998- 2019 .
# Mean of Kilometer driven is ~58K .

# %%
#visuallizing missing values
plt.figure(figsize=(14,6))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
sns.histplot(df['Price'],kde=True,bins=200)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %% [raw]
# Price is right skewed

# %%
plt.figure(figsize=(20, 6))
sns.countplot(data=df, x='Year')
# Out:
# <Axes: xlabel='Year', ylabel='count'>

# %% [raw]
# Year is left skewed

# %%
# Fuel_Type vs Price
sns.barplot(x='Fuel_Type',y='Price',data=df)
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='Price'>

# %% [raw]
# Diesel and electric cars have higher price.

# %%
sns.jointplot(data=df,x='Age',y='Price',hue='Transmission')

# %% [raw]
# Automatic cars have higher price than manual.

# %%
plt.figure(figsize=(20, 6))
sns.countplot(data=df, x='Age')
#right skewed
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
plt.figure(figsize=(20, 6))
plt.xticks(rotation=45)
sns.countplot(data=df, x='Brand')
# Out:
# <Axes: xlabel='Brand', ylabel='count'>

# %% [raw]
# Top brands are maruti and hyundai.

# %%
plt.figure(figsize=(20, 6))
plt.xticks(rotation=45)
sns.countplot(data=df, x='Location',hue='Transmission')
# Out:
# <Axes: xlabel='Location', ylabel='count'>

# %% [raw]
# More no of manual cars are there than automatic cars.

# %%
sns.jointplot(data=df,x='Kilometers_Driven',y='Price')

# %% [raw]
# More price for less no of kilometers driven.
# 2-3 outliers can also be seen.

# %%
axes,fig=plt.subplots(1,1,figsize=(10,8))
sns.heatmap(df.corr(),annot=True,cmap="YlGnBu" )
# Out:
# C:\Users\vishakha\AppData\Local\Temp\ipykernel_12948\4284199096.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap="YlGnBu" )
# <Axes: >

# %% [raw]
# Engine has strong positive correlation to Power [0.85]
# Price has positive correlation to Engine[0.7] as well Power [0.78].
# Mileage is negative correlated to Engine,Power,Price.
# Price has negative correlation to age of car.

# %%
#Engine vs Price and Transmimssion
plt.figure(figsize=(5,3))
plt.title("Price VS Engine based on Transmission")
sns.scatterplot(y='Engine', x='Price', hue='Transmission', data=df)
# Out:
# <Axes: title={'center': 'Price VS Engine based on Transmission'}, xlabel='Price', ylabel='Engine'>

# %%
#mileage vs Price 
plt.figure(figsize=(5,3))
sns.scatterplot(y='Mileage', x='Price', hue='Transmission', data=df)
# Out:
# <Axes: xlabel='Price', ylabel='Mileage'>

# %%
#Price Vs Year Vs Transmission
plt.figure(figsize=(8,4))
plt.title("Price based on manufacturing Year of model")
sns.lineplot(x='Year', y='Price',hue='Transmission',data=df)
# Out:
# <Axes: title={'center': 'Price based on manufacturing Year of model'}, xlabel='Year', ylabel='Price'>

# %% [raw]
# Price is  increasing with time
# Demand of automatic cars is increasing more with time than manual cars.

# %%
#Price Vs Year VS Fuel Type
plt.figure(figsize=(12,6))
plt.title("Price Vs Year VS FuelType")
sns.lineplot(x='Year', y='Price',hue='Fuel_Type',data=df)
# Out:
# <Axes: title={'center': 'Price Vs Year VS FuelType'}, xlabel='Year', ylabel='Price'>

# %%
plt.figure(figsize=(10,4))
plt.title("Price Vs Year VS Owner_Type")
sns.lineplot(x='Year', y='Price',hue='Owner_Type',data=df)
# Out:
# <Axes: title={'center': 'Price Vs Year VS Owner_Type'}, xlabel='Year', ylabel='Price'>

# %% [markdown]
# Handling Missing values

# %% [raw]
# #Colour, No. of Doors, seats is not an important feature to predict the price , so dropping these columns.

# %%
df.drop('Colour',axis=1,inplace=True)
df.drop('No. of Doors',axis=1,inplace=True)
df.drop('Seats',axis=1,inplace=True)

# %%
# counting the number of missing values per row
num_missing = df.isnull().sum(axis=1)

#Investigating how many missing values per row are there for each variable
for n in num_missing.value_counts().sort_index().index:
    if n > 0:
        print("*" *30 , f'\n For the rows with exactly {n} missing values, NAs are found in:')
        n_miss_per_col = df[num_missing == n].isnull().sum()
        print(n_miss_per_col[n_miss_per_col > 0])
        print('\n')
# Out:
# ******************************
#  For the rows with exactly 1 missing values, NAs are found in:
# Transmission       3
# Mileage            1
# Power              1
# New_Price       5072
# dtype: int64
#
#
# ******************************
#  For the rows with exactly 2 missing values, NAs are found in:
# Location              3
# Year                  1
# Kilometers_Driven     2
# Transmission         14
# Owner_Type            5
# Mileage               1
# Engine                3
# Power                14
# New_Price            24
# Age                   1
# dtype: int64
#
#
# ******************************
#  For the rows with exactly 3 missing values, NAs are found in:
# Location              8
# Year                  1
# Kilometers_Driven     6
# Transmission         10
# Owner_Type           10
# Engine               14
# Power                17
# New_Price            32
# Age                   1
# dtype: int64

# %% [raw]
# Since, engine ,power, age ,mileage are significant in predicting new price.
# We can start filling missing values by grouping name and year and fill in missing values with median.

# %%
df['Year'].fillna(df['Year'].median(), inplace=True) 

df['Engine']=df.groupby(['Name','Year'],group_keys=False)['Engine'].apply(lambda x:x.fillna(x.median()))
df['Power']=df.groupby(['Name','Year'],group_keys=False)['Power'].apply(lambda x:x.fillna(x.median()))
df['Mileage']=df.groupby(['Name','Year'],group_keys=False)['Mileage'].apply(lambda x:x.fillna(x.median()))

# %%
col=['Engine','Power','Mileage']
df[col].isnull().sum()
# Out:
# Engine     1
# Power      1
# Mileage    2
# dtype: int64

# %% [raw]
# Still, missing values are there.
# chosing Median to fill the the missing value as there are many outliers, and grouping by model to get more granularity and more accurate values

# %%
df['Mileage']=df.groupby(['Brand','Model'],group_keys=False)['Mileage'].apply(lambda x:x.fillna(x.median()))
df['Age']=df.groupby(['Brand','Model'],group_keys=False)['Age'].apply(lambda x:x.fillna(x.median()))
df['Engine']=df.groupby(['Brand','Model'],group_keys=False)['Engine'].apply(lambda x:x.fillna(x.median()))
df['Power']=df.groupby(['Brand','Model'],group_keys=False)['Power'].apply(lambda x:x.fillna(x.median()))

# %%
df[col].isnull().sum()
# Out:
# Engine     0
# Power      0
# Mileage    2
# dtype: int64

# %% [raw]
# 2 missing values in mileage column --> dropping them

# %%
df.dropna(subset=['Mileage'], inplace=True)
#subset=['Mileage'] specifies that you want to consider only the "Mileage" column when
#determining whether a row has missing values

# %%
df.isnull().sum()
# Out:
# Name                    0
# Location               11
# Year                    0
# Kilometers_Driven       8
# Fuel_Type               0
# Transmission           27
# Owner_Type             15
# Mileage                 0
# Engine                  0
# Power                   0
# New_Price            5127
# Price                   0
# Age                     0
# Brand                   0
# Model                   0
# dtype: int64

# %% [raw]
# Filling missing values in Transmission

# %%
most_frequent_category = df['Transmission'].mode()[0]
df['Transmission'].fillna(most_frequent_category, inplace=True)

# %% [raw]
# Filling missing values in Kilometer_Driven

# %%
mean_kilometers = df['Kilometers_Driven'].mean()
df['Kilometers_Driven'].fillna(mean_kilometers, inplace=True)

# %%
df["Location"] = df["Location"].astype("category")
df['Brand'] =df['Brand'].astype("category")

# %% [raw]
# Dropping remaining rows with missing values as more values cannot be filled based on given features(columns).
# Dropping those rows.

# %%
df.dropna(inplace=True,axis=0)

# %%
df.isnull().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# New_Price            0
# Price                0
# Age                  0
# Brand                0
# Model                0
# dtype: int64

# %%
df.drop(['Name','Model','Year','Brand'],axis=1,inplace=True)

# %% [markdown]
# Model Building
